# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutthuram03/Quantum_Computing_Lab_Experiments/blob/main/EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit qiskit-aer matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer

qc = QuantumCircuit(2, 2)

qc.x(0)
qc.cx(0,1)

print("CNOT Circuit:")
print(qc.draw())

qc.measure([0,1],[0,1])

backend = Aer.get_backend('qasm_simulator')
result = backend.run(qc, shots=1024).result()

print("Output:", result.get_counts())
# Out:
# CNOT Circuit:
#      ┌───┐
# q_0: ┤ X ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# c: 2/══════════
#
# Output: {'11': 1024}

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer

qc = QuantumCircuit(2, 2)

qc.x(0)
qc.swap(0,1)

print("SWAP Circuit:")
print(qc.draw())

qc.measure([0,1],[0,1])

backend = Aer.get_backend('qasm_simulator')
result = backend.run(qc, shots=1024).result()

print("Output:", result.get_counts())
# Out:
# SWAP Circuit:
#      ┌───┐
# q_0: ┤ X ├─X─
#      └───┘ │
# q_1: ──────X─
#
# c: 2/════════
#
# Output: {'10': 1024}

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0,1)

print("Bell Circuit:")
print(qc.draw())

state = Statevector.from_instruction(qc)
print("Statevector:", state.data)
# Out:
# Bell Circuit:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# Statevector: [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer

qc = QuantumCircuit(2,2)

qc.h(0)
qc.cx(0,1)

print("Bell Measurement Circuit:")
print(qc.draw())

qc.measure([0,1],[0,1])

backend = Aer.get_backend('qasm_simulator')
result = backend.run(qc, shots=1024).result()

print("Output:", result.get_counts())
# Out:
# Bell Measurement Circuit:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# c: 2/══════════
#
# Output: {'11': 496, '00': 528}
